# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.Series([1,3,5,6,8])
# Out:
# 0    1
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
df=pd.DataFrame(data=np.arange(1,49).reshape(12,4), columns=['X1','X2','X3','X4'])
df
# Out:
#     X1  X2  X3  X4
# 0    1   2   3   4
# 1    5   6   7   8
# 2    9  10  11  12
# 3   13  14  15  16
# 4   17  18  19  20
# 5   21  22  23  24
# 6   25  26  27  28
# 7   29  30  31  32
# 8   33  34  35  36
# 9   37  38  39  40
# 10  41  42  43  44
# 11  45  46  47  48

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      12 non-null     int32
#  1   X2      12 non-null     int32
#  2   X3      12 non-null     int32
#  3   X4      12 non-null     int32
# dtypes: int32(4)
# memory usage: 320.0 bytes

# %%
df.describe()
# Out:
#               X1         X2         X3         X4
# count  12.000000  12.000000  12.000000  12.000000
# mean   23.000000  24.000000  25.000000  26.000000
# std    14.422205  14.422205  14.422205  14.422205
# min     1.000000   2.000000   3.000000   4.000000
# 25%    12.000000  13.000000  14.000000  15.000000
# 50%    23.000000  24.000000  25.000000  26.000000
# 75%    34.000000  35.000000  36.000000  37.000000
# max    45.000000  46.000000  47.000000  48.000000

# %%
df.sort_values(by="X2", ascending=False)
# Out:
#     X1  X2  X3  X4
# 11  45  46  47  48
# 10  41  42  43  44
# 9   37  38  39  40
# 8   33  34  35  36
# 7   29  30  31  32
# 6   25  26  27  28
# 5   21  22  23  24
# 4   17  18  19  20
# 3   13  14  15  16
# 2    9  10  11  12
# 1    5   6   7   8
# 0    1   2   3   4

# %% [markdown]
# ### 판다스로 데이터가지고 놀기

# %%
df["X1"]
# Out:
# 0      1
# 1      5
# 2      9
# 3     13
# 4     17
# 5     21
# 6     25
# 7     29
# 8     33
# 9     37
# 10    41
# 11    45
# Name: X1, dtype: int32

# %%
df.loc[0]
# Out:
# X1    1
# X2    2
# X3    3
# X4    4
# Name: 0, dtype: int32

# %%
df.loc[0][2]
# Out:
# 3

# %%
df.loc[0]["X3"]
# Out:
# 3

# %%
# df.loc에 2차원 indexing도 가능하다.
# df.loc["row에 대한 조건", "col에 대한 조건"]

df.loc[4,"X2"]
df.loc[[0,3],["X1","X3"]]
df.loc[0:4, "X1":"X3"]
# Out:
#    X1  X2  X3
# 0   1   2   3
# 1   5   6   7
# 2   9  10  11
# 3  13  14  15
# 4  17  18  19

# %%
mask = df["X1"] > 10  # row에 대한 조건
df.loc[mask]

df.loc[df["X2"] >= 20]

df.loc[df["X2"] >= 20, "X4"]
# Out:
# 5     24
# 6     28
# 7     32
# 8     36
# 9     40
# 10    44
# 11    48
# Name: X4, dtype: int32

# %%
df.loc[(df["X3"] >= 10) & (df["X3"] <= 30)]
# Out:
#    X1  X2  X3  X4
# 2   9  10  11  12
# 3  13  14  15  16
# 4  17  18  19  20
# 5  21  22  23  24
# 6  25  26  27  28

# %%
df.loc[(30 < df["X2"]) | (10 > df["X2"])]
# Out:
#     X1  X2  X3  X4
# 0    1   2   3   4
# 1    5   6   7   8
# 8   33  34  35  36
# 9   37  38  39  40
# 10  41  42  43  44
# 11  45  46  47  48

# %%
# row 8번째 까지, column 2번째 까지
df.iloc[3:8, 0:2]
# Out:
#    X1  X2
# 3  13  14
# 4  17  18
# 5  21  22
# 6  25  26
# 7  29  30

# %% [markdown]
# ### 실제 데이터로 사용해보기
# #### 데이터 사이트 : https://www.kaggle.com/c/titanic/data

# %%
titanic = pd.read_csv("./data/titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.loc[titanic["Age"] >= 30, "Name"]
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
#                              ...
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 881                                   Markun, Mr. Johann
# 885                 Rice, Mrs. William (Margaret Norton)
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 330, dtype: object

# %%
pd.pivot_table(data = titanic, index = "Sex", values = "Survived") # mean
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
# 평균, 합계, 수 함께 보기
pd.pivot_table(data=titanic, index="Sex", values="Survived", aggfunc=["mean","sum","count"])

# 유의미하게 여성들이 많이 살아남았다.
# Out:
#             mean      sum    count
#         Survived Survived Survived
# Sex
# female  0.742038      233      314
# male    0.188908      109      577

# %%
pd.pivot_table(data=titanic, index=["Pclass","Sex"], values="Survived", aggfunc=["count","sum","mean"])
# Out:
#                  count      sum      mean
#               Survived Survived  Survived
# Pclass Sex
# 1      female       94       91  0.968085
#        male        122       45  0.368852
# 2      female       76       70  0.921053
#        male        108       17  0.157407
# 3      female      144       72  0.500000
#        male        347       47  0.135447

# %% [markdown]
# ### 엑셀 데이터 병합하기

# %%
from glob import glob
from tqdm.notebook import tqdm
import os

stations_files = glob('./data/Opinet/*.xls')
len(stations_files)
# Out:
# 126

# %%
tmp = pd.read_excel(stations_files[0], header = 2)
tmp
tmp2=pd.read_excel(stations_files[1], header = 2)
pd.concat([tmp, tmp2])
# Out:
#        지역                    상호                            주소      상표  \
# 0   서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1   서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 2   서울특별시        (주)삼표에너지 고덕주유소           서울 강동구 고덕로 39 (암사동)   GS칼텍스
# 3   서울특별시     현대오일뱅크㈜직영 명일셀프주유소          서울 강동구 고덕로 168 (명일동)  현대오일뱅크
# 4   서울특별시               방아다리주유소          서울 강동구 동남로 811 (명일동)   SK에너지
# 5   서울특별시          대성석유(주)길동주유소              서울 강동구 천호대로 1168   GS칼텍스
# 6   서울특별시        (주)소모에너지 신월주유소        서울 강동구 양재대로 1323 (성내동)   GS칼텍스
# 7   서울특별시              sk해뜨는주유소         서울 강동구  상일로 132 (강일동)   SK에너지
# 8   서울특별시       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)   S-OIL
# 9   서울특별시        지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)   GS칼텍스
# 10  서울특별시      주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)   SK에너지
# 11  서울특별시        (주)소모에너지 성내주유소         서울 강동구 올림픽로 578 (성내동)   GS칼텍스
# ...

# %%
total = pd.DataFrame()
for file_name in tqdm(stations_files):
        temp = pd.read_excel(file_name, header=2)
        total = pd.concat([total, temp])
        
total = total.sort_values(by="지역")
total = total.reset_index(drop=True)
total
# Out:
#   0%|          | 0/126 [00:00<?, ?it/s]
#          지역          상호                    주소      상표          전화번호 셀프여부  \
# 0       강원도  강릉농협 성산주유소     강원 강릉시 성산면 구산길 16  NH-OIL  033-641-9379    N
# 1       강원도   GS교동택지주유소     강원 강릉시 교동하슬라로 233   GS칼텍스  033-647-5145    Y
# 2       강원도       연곡주유소  강원 강릉시 연곡면 진고개로 2720   S-OIL  033-661-4717    N
# 3       강원도       동국주유소         강원 강릉시 남구길 31  현대오일뱅크  033-641-1234    N
# 4       강원도      무지개주유소   강원 강릉시 강동면 율곡로 2170   GS칼텍스  033-645-4947    N
# ...     ...         ...                   ...     ...           ...  ...
# 5216  인천광역시       송림주유소    인천 동구 염전로 71 (송림동)   S-OIL  032-773-9698    Y
# 5217  인천광역시       대박주유소    인천 동구 송미로 50 (송림동)   알뜰주유소  032-762-3080    N
# 5218  인천광역시       서광주유소        인천 남동구 백범로 471  현대오일뱅크  032-434-6113    N
# 5219  인천광역시       송현주유소   인천 동구 중봉대로 70 (송현동)  현대오일뱅크  032-766-1363    Y
# 5220  인천광역시      구도일주유소       인천 부평구 경인로 1020   S-OIL  032-514-8072    Y
#
#      고급휘발유   휘발유    경유  실내등유
# ...

# %%
total.to_excel("전체주유소_가격.xlsx", index=False)
